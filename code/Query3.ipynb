# %%
# %%configure -f
# {
#     "conf":{
#         "spark.executor.instances": "4",
#         "spark.executor.memory": "2g",
#         "spark.executor.cores": "1"
#     }
# }
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>850</td><td>application_1761923966900_0862</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-24.eu-central-1.compute.internal:20888/proxy/application_1761923966900_0862/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-189.eu-central-1.compute.internal:8042/node/containerlogs/container_1761923966900_0862_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# Current session configs: <tt>{'conf': {'spark.sql.catalog.spark_catalog.type': 'hive', 'spark.executor.instances': '4', 'spark.executor.memory': '2g', 'spark.executor.cores': '1'}, 'kind': 'pyspark'}</tt><br>
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>847</td><td>application_1761923966900_0859</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-24.eu-central-1.compute.internal:20888/proxy/application_1761923966900_0859/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-189.eu-central-1.compute.internal:8042/node/containerlogs/container_1761923966900_0859_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>848</td><td>application_1761923966900_0860</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-24.eu-central-1.compute.internal:20888/proxy/application_1761923966900_0860/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-97.eu-central-1.compute.internal:8042/node/containerlogs/container_1761923966900_0860_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>849</td><td>application_1761923966900_0861</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-24.eu-central-1.compute.internal:20888/proxy/application_1761923966900_0861/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-160.eu-central-1.compute.internal:8042/node/containerlogs/container_1761923966900_0861_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>850</td><td>application_1761923966900_0862</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-24.eu-central-1.compute.internal:20888/proxy/application_1761923966900_0862/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-189.eu-central-1.compute.internal:8042/node/containerlogs/container_1761923966900_0862_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>

# %%
# Implementation 1: DataFrame API
from pyspark.sql.functions import regexp_extract, col
from pyspark.sql import SparkSession
from pyspark.sql.types import StructField, StructType, IntegerType, FloatType, StringType
from pyspark.sql.functions import split, explode, trim, col, collect_list, concat_ws
import time


spark = SparkSession \
    .builder \
    .appName("Query 3 implementation w Dataframe") \
    .getOrCreate()

#Πρωτα πρέπει να μετατρέψουμε το txt αρχειο που περιεχει τις περιγραφές και τα MO codes σε ενα dataframe
codes_df = spark.read.text("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/MO_codes.txt")

# Extract first 4 digits → code
codes_df = codes_df.withColumn("mocodes", regexp_extract(col("value"), r"^(\d{4})", 1))

# Extract the rest → description
codes_df = codes_df.withColumn("description", regexp_extract(col("value"), r"^\d{4}\s+(.*)$", 1))

# Drop original raw column
codes_df = codes_df.drop("value")
#codes_df.show()
#mexri edw eimaste top

# Define the schema for the employees DataFrame
crimes_schema = StructType([
    StructField("dr_no", StringType()),
    StructField("date_rptd", StringType()),
    StructField("date_occ", StringType()),
    StructField("time_occ", StringType()),
    StructField("area", StringType()),
    StructField("area_name", StringType()),
    StructField("rpt_dist_no", StringType()),
    StructField("part_1_2", IntegerType()),
    StructField("crm_cd", StringType()),
    StructField("crm_cd_desc", StringType()),
    StructField("mocodes", StringType()),
    StructField("vict_age", StringType()),
    StructField("vict_sex", StringType()),
    StructField("vict_descent", StringType()),
    StructField("premis_cd", StringType()),
    StructField("premis_desc", StringType()),
    StructField("weapon_used_cd", StringType()),
    StructField("weapon_desc", StringType()),
    StructField("status", StringType()),
    StructField("status_desc", StringType()),
    StructField("crm_cd_1",StringType()),
    StructField("crm_cd_2",StringType()),
    StructField("crm_cd_3",StringType()),
    StructField("crm_cd_4",StringType()),
    StructField("location", StringType()),
    StructField("cross_street", StringType()),
    StructField("lat", FloatType()),
    StructField("lon", FloatType()),
])

crimes_2010_2019_df = spark.read.csv("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2010_2019.csv", \
    header=False, \
    schema=crimes_schema)

crimes_2020_2025_df = spark.read.csv("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv", \
                                     header=False, \
                                     schema=crimes_schema)

#Union both datasets to have all the data available for the query
crimes_total_df = crimes_2010_2019_df.union(crimes_2020_2025_df)

sorted_mo_df = crimes_total_df.groupBy("mocodes").count().orderBy(col("count").desc())
#sorted_mo_df.show()
#Επειδη το MOcodes εχει πολλές τετραδες, θα φτιάξουμε ενα extended dataset με μεμονομενα mocodes για να βρουμε ολα τα description με left outer join και μετα θα τα μετρησουμε για βρουμε εμφανιση για καθε code

# 1. Split mocodes σε array και explode σε ξεχωριστές γραμμές
expanded_df = crimes_total_df \
    .withColumn("mo_array", split(col("mocodes"), " ")) \
    .withColumn("mo_code", explode(col("mo_array"))) \
    .withColumn("mo_code", trim(col("mo_code"))) \
    .filter(col("mo_code") != "")

start_time=time.time()
# 2. Join με το λεξικό των περιγραφών
joined_df = expanded_df.join(
    codes_df,
    expanded_df["mo_code"] == codes_df["mocodes"],
    "left"
)
end_time=time.time()
result_df = joined_df.groupBy("mo_code","description").count().orderBy(col("count").desc())

result_df.show(truncate=False)
result_df.explain("cost")

print("Dataframe API Execution time for Query 3 (join): {:.4f} sec".format(end_time - start_time))
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+--------------------------------------------------------------------------------+-------+
# |mo_code|description                                                                     |count  |
# +-------+--------------------------------------------------------------------------------+-------+
# |0344   |Removes vict property                                                           |1002900|
# |1822   |Stranger                                                                        |548422 |
# |0416   |Hit-Hit w/ weapon                                                               |404773 |
# |0329   |Vandalized                                                                      |377536 |
# |0913   |Victim knew Suspect                                                             |278618 |
# |2000   |Domestic violence                                                               |256188 |
# |1300   |Vehicle involved                                                                |219082 |
# |0400   |Force used                                                                      |213165 |
# |1402   |Evidence Booked (any crime)                                                     |177470 |
# |1609   |Smashed                                                                         |131229 |
# |1309   |Susp uses vehicle                                                               |122108 |
# |1202   |Victim was aged (60 & over) or blind/physically disabled/unable to care for self|120238 |
# |0325   |Took merchandise                                                                |120159 |
# |1814   |Susp is/was current/former boyfriend/girlfriend                                 |118073 |
# |0444   |Pushed                                                                          |116763 |
# |1501   |Other MO (see rpt)                                                              |115589 |
# |1307   |Breaks window                                                                   |113609 |
# |0334   |Brandishes weapon                                                               |105665 |
# |2004   |Suspect is homeless/transient                                                   |93426  |
# |0432   |Intimidation                                                                    |83562  |
# +-------+--------------------------------------------------------------------------------+-------+
# only showing top 20 rows
#
# == Optimized Logical Plan ==
# Sort [count#840L DESC NULLS LAST], true, Statistics(sizeInBytes=1179.0 GiB)
# +- Aggregate [mo_code#712, description#472], [mo_code#712, description#472, count(1) AS count#840L], Statistics(sizeInBytes=1179.0 GiB)
#    +- Project [mo_code#712, description#472], Statistics(sizeInBytes=1010.6 GiB)
#       +- Join LeftOuter, (mo_code#712 = mocodes#468), Statistics(sizeInBytes=1431.6 GiB)
#          :- Project [trim(mo_code#681, None) AS mo_code#712], Statistics(sizeInBytes=48.3 MiB)
#          :  +- Filter NOT (trim(mo_code#681, None) = ), Statistics(sizeInBytes=48.3 MiB)
#          :     +- Generate explode(mo_array#650), [0], false, [mo_code#681], Statistics(sizeInBytes=48.3 MiB)
#          :        +- Union false, false, Statistics(sizeInBytes=48.3 MiB)
#          :           :- Project [split(mocodes#488,  , -1) AS mo_array#650], Statistics(sizeInBytes=32.8 MiB)
#          :           :  +- Filter ((size(split(mocodes#488,  , -1), true) > 0) AND isnotnull(split(mocodes#488,  , -1))), Statistics(sizeInBytes=608.6 MiB)
#          :           :     +- Relation [dr_no#478,date_rptd#479,date_occ#480,time_occ#481,area#482,area_name#483,rpt_dist_no#484,part_1_2#485,crm_cd#486,crm_cd_desc#487,mocodes#488,vict_age#489,vict_sex#490,vict_descent#491,premis_cd#492,premis_desc#493,weapon_used_cd#494,weapon_desc#495,status#496,status_desc#497,crm_cd_1#498,crm_cd_2#499,crm_cd_3#500,crm_cd_4#501,... 4 more fields] csv, Statistics(sizeInBytes=608.6 MiB)
#          :           +- Project [split(mocodes#544,  , -1) AS mo_array#920], Statistics(sizeInBytes=15.5 MiB)
#          :              +- Filter ((size(split(mocodes#544,  , -1), true) > 0) AND isnotnull(split(mocodes#544,  , -1))), Statistics(sizeInBytes=287.6 MiB)
#          :                 +- Relation [dr_no#534,date_rptd#535,date_occ#536,time_occ#537,area#538,area_name#539,rpt_dist_no#540,part_1_2#541,crm_cd#542,crm_cd_desc#543,mocodes#544,vict_age#545,vict_sex#546,vict_descent#547,premis_cd#548,premis_desc#549,weapon_used_cd#550,weapon_desc#551,status#552,status_desc#553,crm_cd_1#554,crm_cd_2#555,crm_cd_3#556,crm_cd_4#557,... 4 more fields] csv, Statistics(sizeInBytes=287.6 MiB)
#          +- Project [regexp_extract(value#466, ^(\d{4}), 1) AS mocodes#468, regexp_extract(value#466, ^\d{4}\s+(.*)$, 1) AS description#472], Statistics(sizeInBytes=29.7 KiB)
#             +- Filter (NOT (regexp_extract(value#466, ^(\d{4}), 1) = ) AND isnotnull(regexp_extract(value#466, ^(\d{4}), 1))), Statistics(sizeInBytes=17.3 KiB)
#                +- Relation [value#466] text, Statistics(sizeInBytes=17.3 KiB)
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Sort [count#840L DESC NULLS LAST], true, 0
#    +- Exchange rangepartitioning(count#840L DESC NULLS LAST, 1000), ENSURE_REQUIREMENTS, [plan_id=630]
#       +- HashAggregate(keys=[mo_code#712, description#472], functions=[count(1)], output=[mo_code#712, description#472, count#840L], schema specialized)
#          +- Exchange hashpartitioning(mo_code#712, description#472, 1000), ENSURE_REQUIREMENTS, [plan_id=627]
#             +- HashAggregate(keys=[mo_code#712, description#472], functions=[partial_count(1)], output=[mo_code#712, description#472, count#855L], schema specialized)
#                +- Project [mo_code#712, description#472]
#                   +- BroadcastHashJoin [mo_code#712], [mocodes#468], LeftOuter, BuildRight, false
#                      :- Project [trim(mo_code#681, None) AS mo_code#712]
#                      :  +- Filter NOT (trim(mo_code#681, None) = )
#                      :     +- Generate explode(mo_array#650), false, [mo_code#681]
#                      :        +- Union
#                      :           :- Project [split(mocodes#488,  , -1) AS mo_array#650]
#                      :           :  +- Filter ((size(split(mocodes#488,  , -1), true) > 0) AND isnotnull(split(mocodes#488,  , -1)))
#                      :           :     +- FileScan csv [mocodes#488] Batched: false, DataFilters: [(size(split(mocodes#488,  , -1), true) > 0), isnotnull(split(mocodes#488,  , -1))], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<mocodes:string>
#                      :           +- Project [split(mocodes#544,  , -1) AS mo_array#920]
#                      :              +- Filter ((size(split(mocodes#544,  , -1), true) > 0) AND isnotnull(split(mocodes#544,  , -1)))
#                      :                 +- FileScan csv [mocodes#544] Batched: false, DataFilters: [(size(split(mocodes#544,  , -1), true) > 0), isnotnull(split(mocodes#544,  , -1))], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<mocodes:string>
#                      +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=622]
#                         +- Project [regexp_extract(value#466, ^(\d{4}), 1) AS mocodes#468, regexp_extract(value#466, ^\d{4}\s+(.*)$, 1) AS description#472]
#                            +- Filter (NOT (regexp_extract(value#466, ^(\d{4}), 1) = ) AND isnotnull(regexp_extract(value#466, ^(\d{4}), 1)))
#                               +- FileScan text [value#466] Batched: false, DataFilters: [NOT (regexp_extract(value#466, ^(\d{4}), 1) = ), isnotnull(regexp_extract(value#466, ^(\d{4}), 1))], Format: Text, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/MO_c..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<value:string>
#
#
# Dataframe API Execution time for Query 3 (join): 0.0111 sec

# %%
#broadcast
from pyspark.sql.functions import broadcast
from pyspark.sql.functions import regexp_extract, col
from pyspark.sql import SparkSession
from pyspark.sql.types import StructField, StructType, IntegerType, FloatType, StringType
from pyspark.sql.functions import split, explode, trim, col, collect_list, concat_ws
import time


spark = SparkSession \
    .builder \
    .appName("Query 3 implementation w Dataframe") \
    .getOrCreate()

#Πρωτα πρέπει να μετατρέψουμε το txt αρχειο που περιεχει τις περιγραφές και τα MO codes σε ενα dataframe
codes_df = spark.read.text("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/MO_codes.txt")

# Extract first 4 digits → code
codes_df = codes_df.withColumn("mocodes", regexp_extract(col("value"), r"^(\d{4})", 1))

# Extract the rest → description
codes_df = codes_df.withColumn("description", regexp_extract(col("value"), r"^\d{4}\s+(.*)$", 1))

# Drop original raw column
codes_df = codes_df.drop("value")
#codes_df.show()
#mexri edw eimaste top

# Define the schema for the employees DataFrame
crimes_schema = StructType([
    StructField("dr_no", StringType()),
    StructField("date_rptd", StringType()),
    StructField("date_occ", StringType()),
    StructField("time_occ", StringType()),
    StructField("area", StringType()),
    StructField("area_name", StringType()),
    StructField("rpt_dist_no", StringType()),
    StructField("part_1_2", IntegerType()),
    StructField("crm_cd", StringType()),
    StructField("crm_cd_desc", StringType()),
    StructField("mocodes", StringType()),
    StructField("vict_age", StringType()),
    StructField("vict_sex", StringType()),
    StructField("vict_descent", StringType()),
    StructField("premis_cd", StringType()),
    StructField("premis_desc", StringType()),
    StructField("weapon_used_cd", StringType()),
    StructField("weapon_desc", StringType()),
    StructField("status", StringType()),
    StructField("status_desc", StringType()),
    StructField("crm_cd_1",StringType()),
    StructField("crm_cd_2",StringType()),
    StructField("crm_cd_3",StringType()),
    StructField("crm_cd_4",StringType()),
    StructField("location", StringType()),
    StructField("cross_street", StringType()),
    StructField("lat", FloatType()),
    StructField("lon", FloatType()),
])

crimes_2010_2019_df = spark.read.csv("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2010_2019.csv", \
    header=False, \
    schema=crimes_schema)

crimes_2020_2025_df = spark.read.csv("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv", \
                                     header=False, \
                                     schema=crimes_schema)

#Union both datasets to have all the data available for the query
crimes_total_df = crimes_2010_2019_df.union(crimes_2020_2025_df)

sorted_mo_df = crimes_total_df.groupBy("mocodes").count().orderBy(col("count").desc())
#sorted_mo_df.show()
#Επειδη το MOcodes εχει πολλές τετραδες, θα φτιάξουμε ενα extended dataset με μεμονομενα mocodes για να βρουμε ολα τα description με left outer join και μετα θα τα μετρησουμε για βρουμε εμφανιση για καθε code

# 1. Split mocodes σε array και explode σε ξεχωριστές γραμμές
expanded_df = crimes_total_df \
    .withColumn("mo_array", split(col("mocodes"), " ")) \
    .withColumn("mo_code", explode(col("mo_array"))) \
    .withColumn("mo_code", trim(col("mo_code"))) \
    .filter(col("mo_code") != "")

start_time=time.time()
# 2. Join με το λεξικό των περιγραφών
broadcast_join = expanded_df.join(
    broadcast(codes_df),
    expanded_df["mo_code"] == codes_df["mocodes"],
    "left"
)
end_time=time.time()
broadcast_join.explain(mode="formatted")

result_df = broadcast_join.groupBy("mo_code","description").count().orderBy(col("count").desc())

result_df.show(truncate=False)
result_df.explain("cost")

print("Dataframe API Execution time for Query 3 (broadcast): {:.4f} sec".format(end_time - start_time))
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# == Physical Plan ==
# AdaptiveSparkPlan (16)
# +- BroadcastHashJoin LeftOuter BuildRight (15)
#    :- Project (10)
#    :  +- Filter (9)
#    :     +- Generate (8)
#    :        +- Union (7)
#    :           :- Project (3)
#    :           :  +- Filter (2)
#    :           :     +- Scan csv  (1)
#    :           +- Project (6)
#    :              +- Filter (5)
#    :                 +- Scan csv  (4)
#    +- BroadcastExchange (14)
#       +- Project (13)
#          +- Filter (12)
#             +- Scan text  (11)
#
#
# (1) Scan csv
# Output [28]: [dr_no#2767, date_rptd#2768, date_occ#2769, time_occ#2770, area#2771, area_name#2772, rpt_dist_no#2773, part_1_2#2774, crm_cd#2775, crm_cd_desc#2776, mocodes#2777, vict_age#2778, vict_sex#2779, vict_descent#2780, premis_cd#2781, premis_desc#2782, weapon_used_cd#2783, weapon_desc#2784, status#2785, status_desc#2786, crm_cd_1#2787, crm_cd_2#2788, crm_cd_3#2789, crm_cd_4#2790, location#2791, cross_street#2792, lat#2793, lon#2794]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2010_2019.csv]
# ReadSchema: struct<dr_no:string,date_rptd:string,date_occ:string,time_occ:string,area:string,area_name:string,rpt_dist_no:string,part_1_2:int,crm_cd:string,crm_cd_desc:string,mocodes:string,vict_age:string,vict_sex:string,vict_descent:string,premis_cd:string,premis_desc:string,weapon_used_cd:string,weapon_desc:string,status:string,status_desc:string,crm_cd_1:string,crm_cd_2:string,crm_cd_3:string,crm_cd_4:string,location:string,cross_street:string,lat:float,lon:float>
#
# (2) Filter
# Input [28]: [dr_no#2767, date_rptd#2768, date_occ#2769, time_occ#2770, area#2771, area_name#2772, rpt_dist_no#2773, part_1_2#2774, crm_cd#2775, crm_cd_desc#2776, mocodes#2777, vict_age#2778, vict_sex#2779, vict_descent#2780, premis_cd#2781, premis_desc#2782, weapon_used_cd#2783, weapon_desc#2784, status#2785, status_desc#2786, crm_cd_1#2787, crm_cd_2#2788, crm_cd_3#2789, crm_cd_4#2790, location#2791, cross_street#2792, lat#2793, lon#2794]
# Condition : ((size(split(mocodes#2777,  , -1), true) > 0) AND isnotnull(split(mocodes#2777,  , -1)))
#
# (3) Project
# Output [29]: [dr_no#2767, date_rptd#2768, date_occ#2769, time_occ#2770, area#2771, area_name#2772, rpt_dist_no#2773, part_1_2#2774, crm_cd#2775, crm_cd_desc#2776, mocodes#2777, vict_age#2778, vict_sex#2779, vict_descent#2780, premis_cd#2781, premis_desc#2782, weapon_used_cd#2783, weapon_desc#2784, status#2785, status_desc#2786, crm_cd_1#2787, crm_cd_2#2788, crm_cd_3#2789, crm_cd_4#2790, location#2791, cross_street#2792, lat#2793, lon#2794, split(mocodes#2777,  , -1) AS mo_array#2939]
# Input [28]: [dr_no#2767, date_rptd#2768, date_occ#2769, time_occ#2770, area#2771, area_name#2772, rpt_dist_no#2773, part_1_2#2774, crm_cd#2775, crm_cd_desc#2776, mocodes#2777, vict_age#2778, vict_sex#2779, vict_descent#2780, premis_cd#2781, premis_desc#2782, weapon_used_cd#2783, weapon_desc#2784, status#2785, status_desc#2786, crm_cd_1#2787, crm_cd_2#2788, crm_cd_3#2789, crm_cd_4#2790, location#2791, cross_street#2792, lat#2793, lon#2794]
#
# (4) Scan csv
# Output [28]: [dr_no#2823, date_rptd#2824, date_occ#2825, time_occ#2826, area#2827, area_name#2828, rpt_dist_no#2829, part_1_2#2830, crm_cd#2831, crm_cd_desc#2832, mocodes#2833, vict_age#2834, vict_sex#2835, vict_descent#2836, premis_cd#2837, premis_desc#2838, weapon_used_cd#2839, weapon_desc#2840, status#2841, status_desc#2842, crm_cd_1#2843, crm_cd_2#2844, crm_cd_3#2845, crm_cd_4#2846, location#2847, cross_street#2848, lat#2849, lon#2850]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv]
# ReadSchema: struct<dr_no:string,date_rptd:string,date_occ:string,time_occ:string,area:string,area_name:string,rpt_dist_no:string,part_1_2:int,crm_cd:string,crm_cd_desc:string,mocodes:string,vict_age:string,vict_sex:string,vict_descent:string,premis_cd:string,premis_desc:string,weapon_used_cd:string,weapon_desc:string,status:string,status_desc:string,crm_cd_1:string,crm_cd_2:string,crm_cd_3:string,crm_cd_4:string,location:string,cross_street:string,lat:float,lon:float>
#
# (5) Filter
# Input [28]: [dr_no#2823, date_rptd#2824, date_occ#2825, time_occ#2826, area#2827, area_name#2828, rpt_dist_no#2829, part_1_2#2830, crm_cd#2831, crm_cd_desc#2832, mocodes#2833, vict_age#2834, vict_sex#2835, vict_descent#2836, premis_cd#2837, premis_desc#2838, weapon_used_cd#2839, weapon_desc#2840, status#2841, status_desc#2842, crm_cd_1#2843, crm_cd_2#2844, crm_cd_3#2845, crm_cd_4#2846, location#2847, cross_street#2848, lat#2849, lon#2850]
# Condition : ((size(split(mocodes#2833,  , -1), true) > 0) AND isnotnull(split(mocodes#2833,  , -1)))
#
# (6) Project
# Output [29]: [dr_no#2823, date_rptd#2824, date_occ#2825, time_occ#2826, area#2827, area_name#2828, rpt_dist_no#2829, part_1_2#2830, crm_cd#2831, crm_cd_desc#2832, mocodes#2833, vict_age#2834, vict_sex#2835, vict_descent#2836, premis_cd#2837, premis_desc#2838, weapon_used_cd#2839, weapon_desc#2840, status#2841, status_desc#2842, crm_cd_1#2843, crm_cd_2#2844, crm_cd_3#2845, crm_cd_4#2846, location#2847, cross_street#2848, lat#2849, lon#2850, split(mocodes#2833,  , -1) AS mo_array#3096]
# Input [28]: [dr_no#2823, date_rptd#2824, date_occ#2825, time_occ#2826, area#2827, area_name#2828, rpt_dist_no#2829, part_1_2#2830, crm_cd#2831, crm_cd_desc#2832, mocodes#2833, vict_age#2834, vict_sex#2835, vict_descent#2836, premis_cd#2837, premis_desc#2838, weapon_used_cd#2839, weapon_desc#2840, status#2841, status_desc#2842, crm_cd_1#2843, crm_cd_2#2844, crm_cd_3#2845, crm_cd_4#2846, location#2847, cross_street#2848, lat#2849, lon#2850]
#
# (7) Union
#
# (8) Generate
# Input [29]: [dr_no#2767, date_rptd#2768, date_occ#2769, time_occ#2770, area#2771, area_name#2772, rpt_dist_no#2773, part_1_2#2774, crm_cd#2775, crm_cd_desc#2776, mocodes#2777, vict_age#2778, vict_sex#2779, vict_descent#2780, premis_cd#2781, premis_desc#2782, weapon_used_cd#2783, weapon_desc#2784, status#2785, status_desc#2786, crm_cd_1#2787, crm_cd_2#2788, crm_cd_3#2789, crm_cd_4#2790, location#2791, cross_street#2792, lat#2793, lon#2794, mo_array#2939]
# Arguments: explode(mo_array#2939), [dr_no#2767, date_rptd#2768, date_occ#2769, time_occ#2770, area#2771, area_name#2772, rpt_dist_no#2773, part_1_2#2774, crm_cd#2775, crm_cd_desc#2776, mocodes#2777, vict_age#2778, vict_sex#2779, vict_descent#2780, premis_cd#2781, premis_desc#2782, weapon_used_cd#2783, weapon_desc#2784, status#2785, status_desc#2786, crm_cd_1#2787, crm_cd_2#2788, crm_cd_3#2789, crm_cd_4#2790, ... 5 more fields], false, [mo_code#2970]
#
# (9) Filter
# Input [30]: [dr_no#2767, date_rptd#2768, date_occ#2769, time_occ#2770, area#2771, area_name#2772, rpt_dist_no#2773, part_1_2#2774, crm_cd#2775, crm_cd_desc#2776, mocodes#2777, vict_age#2778, vict_sex#2779, vict_descent#2780, premis_cd#2781, premis_desc#2782, weapon_used_cd#2783, weapon_desc#2784, status#2785, status_desc#2786, crm_cd_1#2787, crm_cd_2#2788, crm_cd_3#2789, crm_cd_4#2790, location#2791, cross_street#2792, lat#2793, lon#2794, mo_array#2939, mo_code#2970]
# Condition : NOT (trim(mo_code#2970, None) = )
#
# (10) Project
# Output [30]: [dr_no#2767, date_rptd#2768, date_occ#2769, time_occ#2770, area#2771, area_name#2772, rpt_dist_no#2773, part_1_2#2774, crm_cd#2775, crm_cd_desc#2776, mocodes#2777, vict_age#2778, vict_sex#2779, vict_descent#2780, premis_cd#2781, premis_desc#2782, weapon_used_cd#2783, weapon_desc#2784, status#2785, status_desc#2786, crm_cd_1#2787, crm_cd_2#2788, crm_cd_3#2789, crm_cd_4#2790, location#2791, cross_street#2792, lat#2793, lon#2794, mo_array#2939, trim(mo_code#2970, None) AS mo_code#3001]
# Input [30]: [dr_no#2767, date_rptd#2768, date_occ#2769, time_occ#2770, area#2771, area_name#2772, rpt_dist_no#2773, part_1_2#2774, crm_cd#2775, crm_cd_desc#2776, mocodes#2777, vict_age#2778, vict_sex#2779, vict_descent#2780, premis_cd#2781, premis_desc#2782, weapon_used_cd#2783, weapon_desc#2784, status#2785, status_desc#2786, crm_cd_1#2787, crm_cd_2#2788, crm_cd_3#2789, crm_cd_4#2790, location#2791, cross_street#2792, lat#2793, lon#2794, mo_array#2939, mo_code#2970]
#
# (11) Scan text
# Output [1]: [value#2755]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/MO_codes.txt]
# ReadSchema: struct<value:string>
#
# (12) Filter
# Input [1]: [value#2755]
# Condition : (NOT (regexp_extract(value#2755, ^(\d{4}), 1) = ) AND isnotnull(regexp_extract(value#2755, ^(\d{4}), 1)))
#
# (13) Project
# Output [2]: [regexp_extract(value#2755, ^(\d{4}), 1) AS mocodes#2757, regexp_extract(value#2755, ^\d{4}\s+(.*)$, 1) AS description#2761]
# Input [1]: [value#2755]
#
# (14) BroadcastExchange
# Input [2]: [mocodes#2757, description#2761]
# Arguments: HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=2061]
#
# (15) BroadcastHashJoin
# Left keys [1]: [mo_code#3001]
# Right keys [1]: [mocodes#2757]
# Join type: LeftOuter
# Join condition: None
#
# (16) AdaptiveSparkPlan
# Output [32]: [dr_no#2767, date_rptd#2768, date_occ#2769, time_occ#2770, area#2771, area_name#2772, rpt_dist_no#2773, part_1_2#2774, crm_cd#2775, crm_cd_desc#2776, mocodes#2777, vict_age#2778, vict_sex#2779, vict_descent#2780, premis_cd#2781, premis_desc#2782, weapon_used_cd#2783, weapon_desc#2784, status#2785, status_desc#2786, crm_cd_1#2787, crm_cd_2#2788, crm_cd_3#2789, crm_cd_4#2790, location#2791, cross_street#2792, lat#2793, lon#2794, mo_array#2939, mo_code#3001, mocodes#2757, description#2761]
# Arguments: isFinalPlan=false
#
#
# +-------+--------------------------------------------------------------------------------+-------+
# |mo_code|description                                                                     |count  |
# +-------+--------------------------------------------------------------------------------+-------+
# |0344   |Removes vict property                                                           |1002900|
# |1822   |Stranger                                                                        |548422 |
# |0416   |Hit-Hit w/ weapon                                                               |404773 |
# |0329   |Vandalized                                                                      |377536 |
# |0913   |Victim knew Suspect                                                             |278618 |
# |2000   |Domestic violence                                                               |256188 |
# |1300   |Vehicle involved                                                                |219082 |
# |0400   |Force used                                                                      |213165 |
# |1402   |Evidence Booked (any crime)                                                     |177470 |
# |1609   |Smashed                                                                         |131229 |
# |1309   |Susp uses vehicle                                                               |122108 |
# |1202   |Victim was aged (60 & over) or blind/physically disabled/unable to care for self|120238 |
# |0325   |Took merchandise                                                                |120159 |
# |1814   |Susp is/was current/former boyfriend/girlfriend                                 |118073 |
# |0444   |Pushed                                                                          |116763 |
# |1501   |Other MO (see rpt)                                                              |115589 |
# |1307   |Breaks window                                                                   |113609 |
# |0334   |Brandishes weapon                                                               |105665 |
# |2004   |Suspect is homeless/transient                                                   |93426  |
# |0432   |Intimidation                                                                    |83562  |
# +-------+--------------------------------------------------------------------------------+-------+
# only showing top 20 rows
#
# == Optimized Logical Plan ==
# Sort [count#3130L DESC NULLS LAST], true, Statistics(sizeInBytes=1179.0 GiB)
# +- Aggregate [mo_code#3001, description#2761], [mo_code#3001, description#2761, count(1) AS count#3130L], Statistics(sizeInBytes=1179.0 GiB)
#    +- Project [mo_code#3001, description#2761], Statistics(sizeInBytes=1010.6 GiB)
#       +- Join LeftOuter, (mo_code#3001 = mocodes#2757), rightHint=(strategy=broadcast), Statistics(sizeInBytes=1431.6 GiB)
#          :- Project [trim(mo_code#2970, None) AS mo_code#3001], Statistics(sizeInBytes=48.3 MiB)
#          :  +- Filter NOT (trim(mo_code#2970, None) = ), Statistics(sizeInBytes=48.3 MiB)
#          :     +- Generate explode(mo_array#2939), [0], false, [mo_code#2970], Statistics(sizeInBytes=48.3 MiB)
#          :        +- Union false, false, Statistics(sizeInBytes=48.3 MiB)
#          :           :- Project [split(mocodes#2777,  , -1) AS mo_array#2939], Statistics(sizeInBytes=32.8 MiB)
#          :           :  +- Filter ((size(split(mocodes#2777,  , -1), true) > 0) AND isnotnull(split(mocodes#2777,  , -1))), Statistics(sizeInBytes=608.6 MiB)
#          :           :     +- Relation [dr_no#2767,date_rptd#2768,date_occ#2769,time_occ#2770,area#2771,area_name#2772,rpt_dist_no#2773,part_1_2#2774,crm_cd#2775,crm_cd_desc#2776,mocodes#2777,vict_age#2778,vict_sex#2779,vict_descent#2780,premis_cd#2781,premis_desc#2782,weapon_used_cd#2783,weapon_desc#2784,status#2785,status_desc#2786,crm_cd_1#2787,crm_cd_2#2788,crm_cd_3#2789,crm_cd_4#2790,... 4 more fields] csv, Statistics(sizeInBytes=608.6 MiB)
#          :           +- Project [split(mocodes#2833,  , -1) AS mo_array#3210], Statistics(sizeInBytes=15.5 MiB)
#          :              +- Filter ((size(split(mocodes#2833,  , -1), true) > 0) AND isnotnull(split(mocodes#2833,  , -1))), Statistics(sizeInBytes=287.6 MiB)
#          :                 +- Relation [dr_no#2823,date_rptd#2824,date_occ#2825,time_occ#2826,area#2827,area_name#2828,rpt_dist_no#2829,part_1_2#2830,crm_cd#2831,crm_cd_desc#2832,mocodes#2833,vict_age#2834,vict_sex#2835,vict_descent#2836,premis_cd#2837,premis_desc#2838,weapon_used_cd#2839,weapon_desc#2840,status#2841,status_desc#2842,crm_cd_1#2843,crm_cd_2#2844,crm_cd_3#2845,crm_cd_4#2846,... 4 more fields] csv, Statistics(sizeInBytes=287.6 MiB)
#          +- Project [regexp_extract(value#2755, ^(\d{4}), 1) AS mocodes#2757, regexp_extract(value#2755, ^\d{4}\s+(.*)$, 1) AS description#2761], Statistics(sizeInBytes=29.7 KiB)
#             +- Filter (NOT (regexp_extract(value#2755, ^(\d{4}), 1) = ) AND isnotnull(regexp_extract(value#2755, ^(\d{4}), 1))), Statistics(sizeInBytes=17.3 KiB)
#                +- Relation [value#2755] text, Statistics(sizeInBytes=17.3 KiB)
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Sort [count#3130L DESC NULLS LAST], true, 0
#    +- Exchange rangepartitioning(count#3130L DESC NULLS LAST, 1000), ENSURE_REQUIREMENTS, [plan_id=2385]
#       +- HashAggregate(keys=[mo_code#3001, description#2761], functions=[count(1)], output=[mo_code#3001, description#2761, count#3130L], schema specialized)
#          +- Exchange hashpartitioning(mo_code#3001, description#2761, 1000), ENSURE_REQUIREMENTS, [plan_id=2382]
#             +- HashAggregate(keys=[mo_code#3001, description#2761], functions=[partial_count(1)], output=[mo_code#3001, description#2761, count#3145L], schema specialized)
#                +- Project [mo_code#3001, description#2761]
#                   +- BroadcastHashJoin [mo_code#3001], [mocodes#2757], LeftOuter, BuildRight, false
#                      :- Project [trim(mo_code#2970, None) AS mo_code#3001]
#                      :  +- Filter NOT (trim(mo_code#2970, None) = )
#                      :     +- Generate explode(mo_array#2939), false, [mo_code#2970]
#                      :        +- Union
#                      :           :- Project [split(mocodes#2777,  , -1) AS mo_array#2939]
#                      :           :  +- Filter ((size(split(mocodes#2777,  , -1), true) > 0) AND isnotnull(split(mocodes#2777,  , -1)))
#                      :           :     +- FileScan csv [mocodes#2777] Batched: false, DataFilters: [(size(split(mocodes#2777,  , -1), true) > 0), isnotnull(split(mocodes#2777,  , -1))], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<mocodes:string>
#                      :           +- Project [split(mocodes#2833,  , -1) AS mo_array#3210]
#                      :              +- Filter ((size(split(mocodes#2833,  , -1), true) > 0) AND isnotnull(split(mocodes#2833,  , -1)))
#                      :                 +- FileScan csv [mocodes#2833] Batched: false, DataFilters: [(size(split(mocodes#2833,  , -1), true) > 0), isnotnull(split(mocodes#2833,  , -1))], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<mocodes:string>
#                      +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=2377]
#                         +- Project [regexp_extract(value#2755, ^(\d{4}), 1) AS mocodes#2757, regexp_extract(value#2755, ^\d{4}\s+(.*)$, 1) AS description#2761]
#                            +- Filter (NOT (regexp_extract(value#2755, ^(\d{4}), 1) = ) AND isnotnull(regexp_extract(value#2755, ^(\d{4}), 1)))
#                               +- FileScan text [value#2755] Batched: false, DataFilters: [NOT (regexp_extract(value#2755, ^(\d{4}), 1) = ), isnotnull(regexp_extract(value#2755, ^(\d{4}),..., Format: Text, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/MO_c..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<value:string>
#
#
# Dataframe API Execution time for Query 3 (broadcast): 0.0066 sec

# %%
#Merge
from pyspark.sql.functions import regexp_extract, col
from pyspark.sql import SparkSession
from pyspark.sql.types import StructField, StructType, IntegerType, FloatType, StringType
from pyspark.sql.functions import split, explode, trim, col, collect_list, concat_ws
import time


spark = SparkSession \
    .builder \
    .appName("Query 3 implementation w Dataframe") \
    .getOrCreate()

#Πρωτα πρέπει να μετατρέψουμε το txt αρχειο που περιεχει τις περιγραφές και τα MO codes σε ενα dataframe
codes_df = spark.read.text("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/MO_codes.txt")

# Extract first 4 digits → code
codes_df = codes_df.withColumn("mocodes", regexp_extract(col("value"), r"^(\d{4})", 1))

# Extract the rest → description
codes_df = codes_df.withColumn("description", regexp_extract(col("value"), r"^\d{4}\s+(.*)$", 1))

# Drop original raw column
codes_df = codes_df.drop("value")
#codes_df.show()
#mexri edw eimaste top

# Define the schema for the employees DataFrame
crimes_schema = StructType([
    StructField("dr_no", StringType()),
    StructField("date_rptd", StringType()),
    StructField("date_occ", StringType()),
    StructField("time_occ", StringType()),
    StructField("area", StringType()),
    StructField("area_name", StringType()),
    StructField("rpt_dist_no", StringType()),
    StructField("part_1_2", IntegerType()),
    StructField("crm_cd", StringType()),
    StructField("crm_cd_desc", StringType()),
    StructField("mocodes", StringType()),
    StructField("vict_age", StringType()),
    StructField("vict_sex", StringType()),
    StructField("vict_descent", StringType()),
    StructField("premis_cd", StringType()),
    StructField("premis_desc", StringType()),
    StructField("weapon_used_cd", StringType()),
    StructField("weapon_desc", StringType()),
    StructField("status", StringType()),
    StructField("status_desc", StringType()),
    StructField("crm_cd_1",StringType()),
    StructField("crm_cd_2",StringType()),
    StructField("crm_cd_3",StringType()),
    StructField("crm_cd_4",StringType()),
    StructField("location", StringType()),
    StructField("cross_street", StringType()),
    StructField("lat", FloatType()),
    StructField("lon", FloatType()),
])

crimes_2010_2019_df = spark.read.csv("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2010_2019.csv", \
    header=False, \
    schema=crimes_schema)

crimes_2020_2025_df = spark.read.csv("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv", \
                                     header=False, \
                                     schema=crimes_schema)

#Union both datasets to have all the data available for the query
crimes_total_df = crimes_2010_2019_df.union(crimes_2020_2025_df)

sorted_mo_df = crimes_total_df.groupBy("mocodes").count().orderBy(col("count").desc())
#sorted_mo_df.show()
#Επειδη το MOcodes εχει πολλές τετραδες, θα φτιάξουμε ενα extended dataset με μεμονομενα mocodes για να βρουμε ολα τα description με left outer join και μετα θα τα μετρησουμε για βρουμε εμφανιση για καθε code

# 1. Split mocodes σε array και explode σε ξεχωριστές γραμμές
expanded_df = crimes_total_df \
    .withColumn("mo_array", split(col("mocodes"), " ")) \
    .withColumn("mo_code", explode(col("mo_array"))) \
    .withColumn("mo_code", trim(col("mo_code"))) \
    .filter(col("mo_code") != "")

# 2. Join με το λεξικό των περιγραφών
start_time=time.time()
merge_join = expanded_df.hint("merge") \
    .join(codes_df.hint("merge"), expanded_df["mo_code"] == codes_df["mocodes"], "left")
end_time=time.time()
merge_join.explain(mode="formatted")

result_df = merge_join.groupBy("mo_code","description").count().orderBy(col("count").desc())

result_df.show(truncate=False)
#result_df.explain("cost")

print("Dataframe API Execution time for Query 3 (merge): {:.4f} sec".format(end_time - start_time))
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# == Physical Plan ==
# AdaptiveSparkPlan (19)
# +- SortMergeJoin LeftOuter (18)
#    :- Sort (12)
#    :  +- Exchange (11)
#    :     +- Project (10)
#    :        +- Filter (9)
#    :           +- Generate (8)
#    :              +- Union (7)
#    :                 :- Project (3)
#    :                 :  +- Filter (2)
#    :                 :     +- Scan csv  (1)
#    :                 +- Project (6)
#    :                    +- Filter (5)
#    :                       +- Scan csv  (4)
#    +- Sort (17)
#       +- Exchange (16)
#          +- Project (15)
#             +- Filter (14)
#                +- Scan text  (13)
#
#
# (1) Scan csv
# Output [28]: [dr_no#4588, date_rptd#4589, date_occ#4590, time_occ#4591, area#4592, area_name#4593, rpt_dist_no#4594, part_1_2#4595, crm_cd#4596, crm_cd_desc#4597, mocodes#4598, vict_age#4599, vict_sex#4600, vict_descent#4601, premis_cd#4602, premis_desc#4603, weapon_used_cd#4604, weapon_desc#4605, status#4606, status_desc#4607, crm_cd_1#4608, crm_cd_2#4609, crm_cd_3#4610, crm_cd_4#4611, location#4612, cross_street#4613, lat#4614, lon#4615]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2010_2019.csv]
# ReadSchema: struct<dr_no:string,date_rptd:string,date_occ:string,time_occ:string,area:string,area_name:string,rpt_dist_no:string,part_1_2:int,crm_cd:string,crm_cd_desc:string,mocodes:string,vict_age:string,vict_sex:string,vict_descent:string,premis_cd:string,premis_desc:string,weapon_used_cd:string,weapon_desc:string,status:string,status_desc:string,crm_cd_1:string,crm_cd_2:string,crm_cd_3:string,crm_cd_4:string,location:string,cross_street:string,lat:float,lon:float>
#
# (2) Filter
# Input [28]: [dr_no#4588, date_rptd#4589, date_occ#4590, time_occ#4591, area#4592, area_name#4593, rpt_dist_no#4594, part_1_2#4595, crm_cd#4596, crm_cd_desc#4597, mocodes#4598, vict_age#4599, vict_sex#4600, vict_descent#4601, premis_cd#4602, premis_desc#4603, weapon_used_cd#4604, weapon_desc#4605, status#4606, status_desc#4607, crm_cd_1#4608, crm_cd_2#4609, crm_cd_3#4610, crm_cd_4#4611, location#4612, cross_street#4613, lat#4614, lon#4615]
# Condition : ((size(split(mocodes#4598,  , -1), true) > 0) AND isnotnull(split(mocodes#4598,  , -1)))
#
# (3) Project
# Output [29]: [dr_no#4588, date_rptd#4589, date_occ#4590, time_occ#4591, area#4592, area_name#4593, rpt_dist_no#4594, part_1_2#4595, crm_cd#4596, crm_cd_desc#4597, mocodes#4598, vict_age#4599, vict_sex#4600, vict_descent#4601, premis_cd#4602, premis_desc#4603, weapon_used_cd#4604, weapon_desc#4605, status#4606, status_desc#4607, crm_cd_1#4608, crm_cd_2#4609, crm_cd_3#4610, crm_cd_4#4611, location#4612, cross_street#4613, lat#4614, lon#4615, split(mocodes#4598,  , -1) AS mo_array#4760]
# Input [28]: [dr_no#4588, date_rptd#4589, date_occ#4590, time_occ#4591, area#4592, area_name#4593, rpt_dist_no#4594, part_1_2#4595, crm_cd#4596, crm_cd_desc#4597, mocodes#4598, vict_age#4599, vict_sex#4600, vict_descent#4601, premis_cd#4602, premis_desc#4603, weapon_used_cd#4604, weapon_desc#4605, status#4606, status_desc#4607, crm_cd_1#4608, crm_cd_2#4609, crm_cd_3#4610, crm_cd_4#4611, location#4612, cross_street#4613, lat#4614, lon#4615]
#
# (4) Scan csv
# Output [28]: [dr_no#4644, date_rptd#4645, date_occ#4646, time_occ#4647, area#4648, area_name#4649, rpt_dist_no#4650, part_1_2#4651, crm_cd#4652, crm_cd_desc#4653, mocodes#4654, vict_age#4655, vict_sex#4656, vict_descent#4657, premis_cd#4658, premis_desc#4659, weapon_used_cd#4660, weapon_desc#4661, status#4662, status_desc#4663, crm_cd_1#4664, crm_cd_2#4665, crm_cd_3#4666, crm_cd_4#4667, location#4668, cross_street#4669, lat#4670, lon#4671]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv]
# ReadSchema: struct<dr_no:string,date_rptd:string,date_occ:string,time_occ:string,area:string,area_name:string,rpt_dist_no:string,part_1_2:int,crm_cd:string,crm_cd_desc:string,mocodes:string,vict_age:string,vict_sex:string,vict_descent:string,premis_cd:string,premis_desc:string,weapon_used_cd:string,weapon_desc:string,status:string,status_desc:string,crm_cd_1:string,crm_cd_2:string,crm_cd_3:string,crm_cd_4:string,location:string,cross_street:string,lat:float,lon:float>
#
# (5) Filter
# Input [28]: [dr_no#4644, date_rptd#4645, date_occ#4646, time_occ#4647, area#4648, area_name#4649, rpt_dist_no#4650, part_1_2#4651, crm_cd#4652, crm_cd_desc#4653, mocodes#4654, vict_age#4655, vict_sex#4656, vict_descent#4657, premis_cd#4658, premis_desc#4659, weapon_used_cd#4660, weapon_desc#4661, status#4662, status_desc#4663, crm_cd_1#4664, crm_cd_2#4665, crm_cd_3#4666, crm_cd_4#4667, location#4668, cross_street#4669, lat#4670, lon#4671]
# Condition : ((size(split(mocodes#4654,  , -1), true) > 0) AND isnotnull(split(mocodes#4654,  , -1)))
#
# (6) Project
# Output [29]: [dr_no#4644, date_rptd#4645, date_occ#4646, time_occ#4647, area#4648, area_name#4649, rpt_dist_no#4650, part_1_2#4651, crm_cd#4652, crm_cd_desc#4653, mocodes#4654, vict_age#4655, vict_sex#4656, vict_descent#4657, premis_cd#4658, premis_desc#4659, weapon_used_cd#4660, weapon_desc#4661, status#4662, status_desc#4663, crm_cd_1#4664, crm_cd_2#4665, crm_cd_3#4666, crm_cd_4#4667, location#4668, cross_street#4669, lat#4670, lon#4671, split(mocodes#4654,  , -1) AS mo_array#4917]
# Input [28]: [dr_no#4644, date_rptd#4645, date_occ#4646, time_occ#4647, area#4648, area_name#4649, rpt_dist_no#4650, part_1_2#4651, crm_cd#4652, crm_cd_desc#4653, mocodes#4654, vict_age#4655, vict_sex#4656, vict_descent#4657, premis_cd#4658, premis_desc#4659, weapon_used_cd#4660, weapon_desc#4661, status#4662, status_desc#4663, crm_cd_1#4664, crm_cd_2#4665, crm_cd_3#4666, crm_cd_4#4667, location#4668, cross_street#4669, lat#4670, lon#4671]
#
# (7) Union
#
# (8) Generate
# Input [29]: [dr_no#4588, date_rptd#4589, date_occ#4590, time_occ#4591, area#4592, area_name#4593, rpt_dist_no#4594, part_1_2#4595, crm_cd#4596, crm_cd_desc#4597, mocodes#4598, vict_age#4599, vict_sex#4600, vict_descent#4601, premis_cd#4602, premis_desc#4603, weapon_used_cd#4604, weapon_desc#4605, status#4606, status_desc#4607, crm_cd_1#4608, crm_cd_2#4609, crm_cd_3#4610, crm_cd_4#4611, location#4612, cross_street#4613, lat#4614, lon#4615, mo_array#4760]
# Arguments: explode(mo_array#4760), [dr_no#4588, date_rptd#4589, date_occ#4590, time_occ#4591, area#4592, area_name#4593, rpt_dist_no#4594, part_1_2#4595, crm_cd#4596, crm_cd_desc#4597, mocodes#4598, vict_age#4599, vict_sex#4600, vict_descent#4601, premis_cd#4602, premis_desc#4603, weapon_used_cd#4604, weapon_desc#4605, status#4606, status_desc#4607, crm_cd_1#4608, crm_cd_2#4609, crm_cd_3#4610, crm_cd_4#4611, ... 5 more fields], false, [mo_code#4791]
#
# (9) Filter
# Input [30]: [dr_no#4588, date_rptd#4589, date_occ#4590, time_occ#4591, area#4592, area_name#4593, rpt_dist_no#4594, part_1_2#4595, crm_cd#4596, crm_cd_desc#4597, mocodes#4598, vict_age#4599, vict_sex#4600, vict_descent#4601, premis_cd#4602, premis_desc#4603, weapon_used_cd#4604, weapon_desc#4605, status#4606, status_desc#4607, crm_cd_1#4608, crm_cd_2#4609, crm_cd_3#4610, crm_cd_4#4611, location#4612, cross_street#4613, lat#4614, lon#4615, mo_array#4760, mo_code#4791]
# Condition : NOT (trim(mo_code#4791, None) = )
#
# (10) Project
# Output [30]: [dr_no#4588, date_rptd#4589, date_occ#4590, time_occ#4591, area#4592, area_name#4593, rpt_dist_no#4594, part_1_2#4595, crm_cd#4596, crm_cd_desc#4597, mocodes#4598, vict_age#4599, vict_sex#4600, vict_descent#4601, premis_cd#4602, premis_desc#4603, weapon_used_cd#4604, weapon_desc#4605, status#4606, status_desc#4607, crm_cd_1#4608, crm_cd_2#4609, crm_cd_3#4610, crm_cd_4#4611, location#4612, cross_street#4613, lat#4614, lon#4615, mo_array#4760, trim(mo_code#4791, None) AS mo_code#4822]
# Input [30]: [dr_no#4588, date_rptd#4589, date_occ#4590, time_occ#4591, area#4592, area_name#4593, rpt_dist_no#4594, part_1_2#4595, crm_cd#4596, crm_cd_desc#4597, mocodes#4598, vict_age#4599, vict_sex#4600, vict_descent#4601, premis_cd#4602, premis_desc#4603, weapon_used_cd#4604, weapon_desc#4605, status#4606, status_desc#4607, crm_cd_1#4608, crm_cd_2#4609, crm_cd_3#4610, crm_cd_4#4611, location#4612, cross_street#4613, lat#4614, lon#4615, mo_array#4760, mo_code#4791]
#
# (11) Exchange
# Input [30]: [dr_no#4588, date_rptd#4589, date_occ#4590, time_occ#4591, area#4592, area_name#4593, rpt_dist_no#4594, part_1_2#4595, crm_cd#4596, crm_cd_desc#4597, mocodes#4598, vict_age#4599, vict_sex#4600, vict_descent#4601, premis_cd#4602, premis_desc#4603, weapon_used_cd#4604, weapon_desc#4605, status#4606, status_desc#4607, crm_cd_1#4608, crm_cd_2#4609, crm_cd_3#4610, crm_cd_4#4611, location#4612, cross_street#4613, lat#4614, lon#4615, mo_array#4760, mo_code#4822]
# Arguments: hashpartitioning(mo_code#4822, 1000), ENSURE_REQUIREMENTS, [plan_id=3404]
#
# (12) Sort
# Input [30]: [dr_no#4588, date_rptd#4589, date_occ#4590, time_occ#4591, area#4592, area_name#4593, rpt_dist_no#4594, part_1_2#4595, crm_cd#4596, crm_cd_desc#4597, mocodes#4598, vict_age#4599, vict_sex#4600, vict_descent#4601, premis_cd#4602, premis_desc#4603, weapon_used_cd#4604, weapon_desc#4605, status#4606, status_desc#4607, crm_cd_1#4608, crm_cd_2#4609, crm_cd_3#4610, crm_cd_4#4611, location#4612, cross_street#4613, lat#4614, lon#4615, mo_array#4760, mo_code#4822]
# Arguments: [mo_code#4822 ASC NULLS FIRST], false, 0
#
# (13) Scan text
# Output [1]: [value#4576]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/MO_codes.txt]
# ReadSchema: struct<value:string>
#
# (14) Filter
# Input [1]: [value#4576]
# Condition : (NOT (regexp_extract(value#4576, ^(\d{4}), 1) = ) AND isnotnull(regexp_extract(value#4576, ^(\d{4}), 1)))
#
# (15) Project
# Output [2]: [regexp_extract(value#4576, ^(\d{4}), 1) AS mocodes#4578, regexp_extract(value#4576, ^\d{4}\s+(.*)$, 1) AS description#4582]
# Input [1]: [value#4576]
#
# (16) Exchange
# Input [2]: [mocodes#4578, description#4582]
# Arguments: hashpartitioning(mocodes#4578, 1000), ENSURE_REQUIREMENTS, [plan_id=3405]
#
# (17) Sort
# Input [2]: [mocodes#4578, description#4582]
# Arguments: [mocodes#4578 ASC NULLS FIRST], false, 0
#
# (18) SortMergeJoin
# Left keys [1]: [mo_code#4822]
# Right keys [1]: [mocodes#4578]
# Join type: LeftOuter
# Join condition: None
#
# (19) AdaptiveSparkPlan
# Output [32]: [dr_no#4588, date_rptd#4589, date_occ#4590, time_occ#4591, area#4592, area_name#4593, rpt_dist_no#4594, part_1_2#4595, crm_cd#4596, crm_cd_desc#4597, mocodes#4598, vict_age#4599, vict_sex#4600, vict_descent#4601, premis_cd#4602, premis_desc#4603, weapon_used_cd#4604, weapon_desc#4605, status#4606, status_desc#4607, crm_cd_1#4608, crm_cd_2#4609, crm_cd_3#4610, crm_cd_4#4611, location#4612, cross_street#4613, lat#4614, lon#4615, mo_array#4760, mo_code#4822, mocodes#4578, description#4582]
# Arguments: isFinalPlan=false
#
#
# +-------+--------------------------------------------------------------------------------+-------+
# |mo_code|description                                                                     |count  |
# +-------+--------------------------------------------------------------------------------+-------+
# |0344   |Removes vict property                                                           |1002900|
# |1822   |Stranger                                                                        |548422 |
# |0416   |Hit-Hit w/ weapon                                                               |404773 |
# |0329   |Vandalized                                                                      |377536 |
# |0913   |Victim knew Suspect                                                             |278618 |
# |2000   |Domestic violence                                                               |256188 |
# |1300   |Vehicle involved                                                                |219082 |
# |0400   |Force used                                                                      |213165 |
# |1402   |Evidence Booked (any crime)                                                     |177470 |
# |1609   |Smashed                                                                         |131229 |
# |1309   |Susp uses vehicle                                                               |122108 |
# |1202   |Victim was aged (60 & over) or blind/physically disabled/unable to care for self|120238 |
# |0325   |Took merchandise                                                                |120159 |
# |1814   |Susp is/was current/former boyfriend/girlfriend                                 |118073 |
# |0444   |Pushed                                                                          |116763 |
# |1501   |Other MO (see rpt)                                                              |115589 |
# |1307   |Breaks window                                                                   |113609 |
# |0334   |Brandishes weapon                                                               |105665 |
# |2004   |Suspect is homeless/transient                                                   |93426  |
# |0432   |Intimidation                                                                    |83562  |
# +-------+--------------------------------------------------------------------------------+-------+
# only showing top 20 rows
#
# Dataframe API Execution time for Query 3 (merge): 0.0087 sec

# %%
#shuffle hash
from pyspark.sql.functions import regexp_extract, col
from pyspark.sql import SparkSession
from pyspark.sql.types import StructField, StructType, IntegerType, FloatType, StringType
from pyspark.sql.functions import split, explode, trim, col, collect_list, concat_ws
import time


spark = SparkSession \
    .builder \
    .appName("Query 3 implementation w Dataframe") \
    .getOrCreate()

#Πρωτα πρέπει να μετατρέψουμε το txt αρχειο που περιεχει τις περιγραφές και τα MO codes σε ενα dataframe
codes_df = spark.read.text("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/MO_codes.txt")

# Extract first 4 digits → code
codes_df = codes_df.withColumn("mocodes", regexp_extract(col("value"), r"^(\d{4})", 1))

# Extract the rest → description
codes_df = codes_df.withColumn("description", regexp_extract(col("value"), r"^\d{4}\s+(.*)$", 1))

# Drop original raw column
codes_df = codes_df.drop("value")
#codes_df.show()
#mexri edw eimaste top

# Define the schema for the employees DataFrame
crimes_schema = StructType([
    StructField("dr_no", StringType()),
    StructField("date_rptd", StringType()),
    StructField("date_occ", StringType()),
    StructField("time_occ", StringType()),
    StructField("area", StringType()),
    StructField("area_name", StringType()),
    StructField("rpt_dist_no", StringType()),
    StructField("part_1_2", IntegerType()),
    StructField("crm_cd", StringType()),
    StructField("crm_cd_desc", StringType()),
    StructField("mocodes", StringType()),
    StructField("vict_age", StringType()),
    StructField("vict_sex", StringType()),
    StructField("vict_descent", StringType()),
    StructField("premis_cd", StringType()),
    StructField("premis_desc", StringType()),
    StructField("weapon_used_cd", StringType()),
    StructField("weapon_desc", StringType()),
    StructField("status", StringType()),
    StructField("status_desc", StringType()),
    StructField("crm_cd_1",StringType()),
    StructField("crm_cd_2",StringType()),
    StructField("crm_cd_3",StringType()),
    StructField("crm_cd_4",StringType()),
    StructField("location", StringType()),
    StructField("cross_street", StringType()),
    StructField("lat", FloatType()),
    StructField("lon", FloatType()),
])

crimes_2010_2019_df = spark.read.csv("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2010_2019.csv", \
    header=False, \
    schema=crimes_schema)

crimes_2020_2025_df = spark.read.csv("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv", \
                                     header=False, \
                                     schema=crimes_schema)

#Union both datasets to have all the data available for the query
crimes_total_df = crimes_2010_2019_df.union(crimes_2020_2025_df)

sorted_mo_df = crimes_total_df.groupBy("mocodes").count().orderBy(col("count").desc())
#sorted_mo_df.show()
#Επειδη το MOcodes εχει πολλές τετραδες, θα φτιάξουμε ενα extended dataset με μεμονομενα mocodes για να βρουμε ολα τα description με left outer join και μετα θα τα μετρησουμε για βρουμε εμφανιση για καθε code

# 1. Split mocodes σε array και explode σε ξεχωριστές γραμμές
expanded_df = crimes_total_df \
    .withColumn("mo_array", split(col("mocodes"), " ")) \
    .withColumn("mo_code", explode(col("mo_array"))) \
    .withColumn("mo_code", trim(col("mo_code"))) \
    .filter(col("mo_code") != "")

# 2. Join με το λεξικό των περιγραφών
start_time=time.time()
shuffle_hash_join = expanded_df.hint("shuffle_hash") \
    .join(codes_df.hint("shuffle_hash"), expanded_df["mo_code"] == codes_df["mocodes"], "left")
end_time=time.time()
shuffle_hash_join.explain(mode="formatted")

result_df = shuffle_hash_join.groupBy("mo_code","description").count().orderBy(col("count").desc())

result_df.show(truncate=False)
#result_df.explain("cost")

print("Dataframe API Execution time for Query 3 (shuffle hash): {:.4f} sec".format(end_time - start_time))
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# == Physical Plan ==
# AdaptiveSparkPlan (17)
# +- ShuffledHashJoin LeftOuter BuildRight (16)
#    :- Exchange (11)
#    :  +- Project (10)
#    :     +- Filter (9)
#    :        +- Generate (8)
#    :           +- Union (7)
#    :              :- Project (3)
#    :              :  +- Filter (2)
#    :              :     +- Scan csv  (1)
#    :              +- Project (6)
#    :                 +- Filter (5)
#    :                    +- Scan csv  (4)
#    +- Exchange (15)
#       +- Project (14)
#          +- Filter (13)
#             +- Scan text  (12)
#
#
# (1) Scan csv
# Output [28]: [dr_no#3678, date_rptd#3679, date_occ#3680, time_occ#3681, area#3682, area_name#3683, rpt_dist_no#3684, part_1_2#3685, crm_cd#3686, crm_cd_desc#3687, mocodes#3688, vict_age#3689, vict_sex#3690, vict_descent#3691, premis_cd#3692, premis_desc#3693, weapon_used_cd#3694, weapon_desc#3695, status#3696, status_desc#3697, crm_cd_1#3698, crm_cd_2#3699, crm_cd_3#3700, crm_cd_4#3701, location#3702, cross_street#3703, lat#3704, lon#3705]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2010_2019.csv]
# ReadSchema: struct<dr_no:string,date_rptd:string,date_occ:string,time_occ:string,area:string,area_name:string,rpt_dist_no:string,part_1_2:int,crm_cd:string,crm_cd_desc:string,mocodes:string,vict_age:string,vict_sex:string,vict_descent:string,premis_cd:string,premis_desc:string,weapon_used_cd:string,weapon_desc:string,status:string,status_desc:string,crm_cd_1:string,crm_cd_2:string,crm_cd_3:string,crm_cd_4:string,location:string,cross_street:string,lat:float,lon:float>
#
# (2) Filter
# Input [28]: [dr_no#3678, date_rptd#3679, date_occ#3680, time_occ#3681, area#3682, area_name#3683, rpt_dist_no#3684, part_1_2#3685, crm_cd#3686, crm_cd_desc#3687, mocodes#3688, vict_age#3689, vict_sex#3690, vict_descent#3691, premis_cd#3692, premis_desc#3693, weapon_used_cd#3694, weapon_desc#3695, status#3696, status_desc#3697, crm_cd_1#3698, crm_cd_2#3699, crm_cd_3#3700, crm_cd_4#3701, location#3702, cross_street#3703, lat#3704, lon#3705]
# Condition : ((size(split(mocodes#3688,  , -1), true) > 0) AND isnotnull(split(mocodes#3688,  , -1)))
#
# (3) Project
# Output [29]: [dr_no#3678, date_rptd#3679, date_occ#3680, time_occ#3681, area#3682, area_name#3683, rpt_dist_no#3684, part_1_2#3685, crm_cd#3686, crm_cd_desc#3687, mocodes#3688, vict_age#3689, vict_sex#3690, vict_descent#3691, premis_cd#3692, premis_desc#3693, weapon_used_cd#3694, weapon_desc#3695, status#3696, status_desc#3697, crm_cd_1#3698, crm_cd_2#3699, crm_cd_3#3700, crm_cd_4#3701, location#3702, cross_street#3703, lat#3704, lon#3705, split(mocodes#3688,  , -1) AS mo_array#3850]
# Input [28]: [dr_no#3678, date_rptd#3679, date_occ#3680, time_occ#3681, area#3682, area_name#3683, rpt_dist_no#3684, part_1_2#3685, crm_cd#3686, crm_cd_desc#3687, mocodes#3688, vict_age#3689, vict_sex#3690, vict_descent#3691, premis_cd#3692, premis_desc#3693, weapon_used_cd#3694, weapon_desc#3695, status#3696, status_desc#3697, crm_cd_1#3698, crm_cd_2#3699, crm_cd_3#3700, crm_cd_4#3701, location#3702, cross_street#3703, lat#3704, lon#3705]
#
# (4) Scan csv
# Output [28]: [dr_no#3734, date_rptd#3735, date_occ#3736, time_occ#3737, area#3738, area_name#3739, rpt_dist_no#3740, part_1_2#3741, crm_cd#3742, crm_cd_desc#3743, mocodes#3744, vict_age#3745, vict_sex#3746, vict_descent#3747, premis_cd#3748, premis_desc#3749, weapon_used_cd#3750, weapon_desc#3751, status#3752, status_desc#3753, crm_cd_1#3754, crm_cd_2#3755, crm_cd_3#3756, crm_cd_4#3757, location#3758, cross_street#3759, lat#3760, lon#3761]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv]
# ReadSchema: struct<dr_no:string,date_rptd:string,date_occ:string,time_occ:string,area:string,area_name:string,rpt_dist_no:string,part_1_2:int,crm_cd:string,crm_cd_desc:string,mocodes:string,vict_age:string,vict_sex:string,vict_descent:string,premis_cd:string,premis_desc:string,weapon_used_cd:string,weapon_desc:string,status:string,status_desc:string,crm_cd_1:string,crm_cd_2:string,crm_cd_3:string,crm_cd_4:string,location:string,cross_street:string,lat:float,lon:float>
#
# (5) Filter
# Input [28]: [dr_no#3734, date_rptd#3735, date_occ#3736, time_occ#3737, area#3738, area_name#3739, rpt_dist_no#3740, part_1_2#3741, crm_cd#3742, crm_cd_desc#3743, mocodes#3744, vict_age#3745, vict_sex#3746, vict_descent#3747, premis_cd#3748, premis_desc#3749, weapon_used_cd#3750, weapon_desc#3751, status#3752, status_desc#3753, crm_cd_1#3754, crm_cd_2#3755, crm_cd_3#3756, crm_cd_4#3757, location#3758, cross_street#3759, lat#3760, lon#3761]
# Condition : ((size(split(mocodes#3744,  , -1), true) > 0) AND isnotnull(split(mocodes#3744,  , -1)))
#
# (6) Project
# Output [29]: [dr_no#3734, date_rptd#3735, date_occ#3736, time_occ#3737, area#3738, area_name#3739, rpt_dist_no#3740, part_1_2#3741, crm_cd#3742, crm_cd_desc#3743, mocodes#3744, vict_age#3745, vict_sex#3746, vict_descent#3747, premis_cd#3748, premis_desc#3749, weapon_used_cd#3750, weapon_desc#3751, status#3752, status_desc#3753, crm_cd_1#3754, crm_cd_2#3755, crm_cd_3#3756, crm_cd_4#3757, location#3758, cross_street#3759, lat#3760, lon#3761, split(mocodes#3744,  , -1) AS mo_array#4007]
# Input [28]: [dr_no#3734, date_rptd#3735, date_occ#3736, time_occ#3737, area#3738, area_name#3739, rpt_dist_no#3740, part_1_2#3741, crm_cd#3742, crm_cd_desc#3743, mocodes#3744, vict_age#3745, vict_sex#3746, vict_descent#3747, premis_cd#3748, premis_desc#3749, weapon_used_cd#3750, weapon_desc#3751, status#3752, status_desc#3753, crm_cd_1#3754, crm_cd_2#3755, crm_cd_3#3756, crm_cd_4#3757, location#3758, cross_street#3759, lat#3760, lon#3761]
#
# (7) Union
#
# (8) Generate
# Input [29]: [dr_no#3678, date_rptd#3679, date_occ#3680, time_occ#3681, area#3682, area_name#3683, rpt_dist_no#3684, part_1_2#3685, crm_cd#3686, crm_cd_desc#3687, mocodes#3688, vict_age#3689, vict_sex#3690, vict_descent#3691, premis_cd#3692, premis_desc#3693, weapon_used_cd#3694, weapon_desc#3695, status#3696, status_desc#3697, crm_cd_1#3698, crm_cd_2#3699, crm_cd_3#3700, crm_cd_4#3701, location#3702, cross_street#3703, lat#3704, lon#3705, mo_array#3850]
# Arguments: explode(mo_array#3850), [dr_no#3678, date_rptd#3679, date_occ#3680, time_occ#3681, area#3682, area_name#3683, rpt_dist_no#3684, part_1_2#3685, crm_cd#3686, crm_cd_desc#3687, mocodes#3688, vict_age#3689, vict_sex#3690, vict_descent#3691, premis_cd#3692, premis_desc#3693, weapon_used_cd#3694, weapon_desc#3695, status#3696, status_desc#3697, crm_cd_1#3698, crm_cd_2#3699, crm_cd_3#3700, crm_cd_4#3701, ... 5 more fields], false, [mo_code#3881]
#
# (9) Filter
# Input [30]: [dr_no#3678, date_rptd#3679, date_occ#3680, time_occ#3681, area#3682, area_name#3683, rpt_dist_no#3684, part_1_2#3685, crm_cd#3686, crm_cd_desc#3687, mocodes#3688, vict_age#3689, vict_sex#3690, vict_descent#3691, premis_cd#3692, premis_desc#3693, weapon_used_cd#3694, weapon_desc#3695, status#3696, status_desc#3697, crm_cd_1#3698, crm_cd_2#3699, crm_cd_3#3700, crm_cd_4#3701, location#3702, cross_street#3703, lat#3704, lon#3705, mo_array#3850, mo_code#3881]
# Condition : NOT (trim(mo_code#3881, None) = )
#
# (10) Project
# Output [30]: [dr_no#3678, date_rptd#3679, date_occ#3680, time_occ#3681, area#3682, area_name#3683, rpt_dist_no#3684, part_1_2#3685, crm_cd#3686, crm_cd_desc#3687, mocodes#3688, vict_age#3689, vict_sex#3690, vict_descent#3691, premis_cd#3692, premis_desc#3693, weapon_used_cd#3694, weapon_desc#3695, status#3696, status_desc#3697, crm_cd_1#3698, crm_cd_2#3699, crm_cd_3#3700, crm_cd_4#3701, location#3702, cross_street#3703, lat#3704, lon#3705, mo_array#3850, trim(mo_code#3881, None) AS mo_code#3912]
# Input [30]: [dr_no#3678, date_rptd#3679, date_occ#3680, time_occ#3681, area#3682, area_name#3683, rpt_dist_no#3684, part_1_2#3685, crm_cd#3686, crm_cd_desc#3687, mocodes#3688, vict_age#3689, vict_sex#3690, vict_descent#3691, premis_cd#3692, premis_desc#3693, weapon_used_cd#3694, weapon_desc#3695, status#3696, status_desc#3697, crm_cd_1#3698, crm_cd_2#3699, crm_cd_3#3700, crm_cd_4#3701, location#3702, cross_street#3703, lat#3704, lon#3705, mo_array#3850, mo_code#3881]
#
# (11) Exchange
# Input [30]: [dr_no#3678, date_rptd#3679, date_occ#3680, time_occ#3681, area#3682, area_name#3683, rpt_dist_no#3684, part_1_2#3685, crm_cd#3686, crm_cd_desc#3687, mocodes#3688, vict_age#3689, vict_sex#3690, vict_descent#3691, premis_cd#3692, premis_desc#3693, weapon_used_cd#3694, weapon_desc#3695, status#3696, status_desc#3697, crm_cd_1#3698, crm_cd_2#3699, crm_cd_3#3700, crm_cd_4#3701, location#3702, cross_street#3703, lat#3704, lon#3705, mo_array#3850, mo_code#3912]
# Arguments: hashpartitioning(mo_code#3912, 1000), ENSURE_REQUIREMENTS, [plan_id=2807]
#
# (12) Scan text
# Output [1]: [value#3666]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/MO_codes.txt]
# ReadSchema: struct<value:string>
#
# (13) Filter
# Input [1]: [value#3666]
# Condition : (NOT (regexp_extract(value#3666, ^(\d{4}), 1) = ) AND isnotnull(regexp_extract(value#3666, ^(\d{4}), 1)))
#
# (14) Project
# Output [2]: [regexp_extract(value#3666, ^(\d{4}), 1) AS mocodes#3668, regexp_extract(value#3666, ^\d{4}\s+(.*)$, 1) AS description#3672]
# Input [1]: [value#3666]
#
# (15) Exchange
# Input [2]: [mocodes#3668, description#3672]
# Arguments: hashpartitioning(mocodes#3668, 1000), ENSURE_REQUIREMENTS, [plan_id=2808]
#
# (16) ShuffledHashJoin
# Left keys [1]: [mo_code#3912]
# Right keys [1]: [mocodes#3668]
# Join type: LeftOuter
# Join condition: None
#
# (17) AdaptiveSparkPlan
# Output [32]: [dr_no#3678, date_rptd#3679, date_occ#3680, time_occ#3681, area#3682, area_name#3683, rpt_dist_no#3684, part_1_2#3685, crm_cd#3686, crm_cd_desc#3687, mocodes#3688, vict_age#3689, vict_sex#3690, vict_descent#3691, premis_cd#3692, premis_desc#3693, weapon_used_cd#3694, weapon_desc#3695, status#3696, status_desc#3697, crm_cd_1#3698, crm_cd_2#3699, crm_cd_3#3700, crm_cd_4#3701, location#3702, cross_street#3703, lat#3704, lon#3705, mo_array#3850, mo_code#3912, mocodes#3668, description#3672]
# Arguments: isFinalPlan=false
#
#
# +-------+--------------------------------------------------------------------------------+-------+
# |mo_code|description                                                                     |count  |
# +-------+--------------------------------------------------------------------------------+-------+
# |0344   |Removes vict property                                                           |1002900|
# |1822   |Stranger                                                                        |548422 |
# |0416   |Hit-Hit w/ weapon                                                               |404773 |
# |0329   |Vandalized                                                                      |377536 |
# |0913   |Victim knew Suspect                                                             |278618 |
# |2000   |Domestic violence                                                               |256188 |
# |1300   |Vehicle involved                                                                |219082 |
# |0400   |Force used                                                                      |213165 |
# |1402   |Evidence Booked (any crime)                                                     |177470 |
# |1609   |Smashed                                                                         |131229 |
# |1309   |Susp uses vehicle                                                               |122108 |
# |1202   |Victim was aged (60 & over) or blind/physically disabled/unable to care for self|120238 |
# |0325   |Took merchandise                                                                |120159 |
# |1814   |Susp is/was current/former boyfriend/girlfriend                                 |118073 |
# |0444   |Pushed                                                                          |116763 |
# |1501   |Other MO (see rpt)                                                              |115589 |
# |1307   |Breaks window                                                                   |113609 |
# |0334   |Brandishes weapon                                                               |105665 |
# |2004   |Suspect is homeless/transient                                                   |93426  |
# |0432   |Intimidation                                                                    |83562  |
# +-------+--------------------------------------------------------------------------------+-------+
# only showing top 20 rows
#
# Dataframe API Execution time for Query 3 (shuffle hash): 0.0094 sec

# %%
#shuffle replicate nl
from pyspark.sql.functions import regexp_extract, col
from pyspark.sql import SparkSession
from pyspark.sql.types import StructField, StructType, IntegerType, FloatType, StringType
from pyspark.sql.functions import split, explode, trim, col, collect_list, concat_ws
import time


spark = SparkSession \
    .builder \
    .appName("Query 3 implementation w Dataframe") \
    .getOrCreate()

#Πρωτα πρέπει να μετατρέψουμε το txt αρχειο που περιεχει τις περιγραφές και τα MO codes σε ενα dataframe
codes_df = spark.read.text("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/MO_codes.txt")

# Extract first 4 digits → code
codes_df = codes_df.withColumn("mocodes", regexp_extract(col("value"), r"^(\d{4})", 1))

# Extract the rest → description
codes_df = codes_df.withColumn("description", regexp_extract(col("value"), r"^\d{4}\s+(.*)$", 1))

# Drop original raw column
codes_df = codes_df.drop("value")
#codes_df.show()
#mexri edw eimaste top

# Define the schema for the employees DataFrame
crimes_schema = StructType([
    StructField("dr_no", StringType()),
    StructField("date_rptd", StringType()),
    StructField("date_occ", StringType()),
    StructField("time_occ", StringType()),
    StructField("area", StringType()),
    StructField("area_name", StringType()),
    StructField("rpt_dist_no", StringType()),
    StructField("part_1_2", IntegerType()),
    StructField("crm_cd", StringType()),
    StructField("crm_cd_desc", StringType()),
    StructField("mocodes", StringType()),
    StructField("vict_age", StringType()),
    StructField("vict_sex", StringType()),
    StructField("vict_descent", StringType()),
    StructField("premis_cd", StringType()),
    StructField("premis_desc", StringType()),
    StructField("weapon_used_cd", StringType()),
    StructField("weapon_desc", StringType()),
    StructField("status", StringType()),
    StructField("status_desc", StringType()),
    StructField("crm_cd_1",StringType()),
    StructField("crm_cd_2",StringType()),
    StructField("crm_cd_3",StringType()),
    StructField("crm_cd_4",StringType()),
    StructField("location", StringType()),
    StructField("cross_street", StringType()),
    StructField("lat", FloatType()),
    StructField("lon", FloatType()),
])

crimes_2010_2019_df = spark.read.csv("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2010_2019.csv", \
    header=False, \
    schema=crimes_schema)

crimes_2020_2025_df = spark.read.csv("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv", \
                                     header=False, \
                                     schema=crimes_schema)

#Union both datasets to have all the data available for the query
crimes_total_df = crimes_2010_2019_df.union(crimes_2020_2025_df)

sorted_mo_df = crimes_total_df.groupBy("mocodes").count().orderBy(col("count").desc())
#sorted_mo_df.show()
#Επειδη το MOcodes εχει πολλές τετραδες, θα φτιάξουμε ενα extended dataset με μεμονομενα mocodes για να βρουμε ολα τα description με left outer join και μετα θα τα μετρησουμε για βρουμε εμφανιση για καθε code

# 1. Split mocodes σε array και explode σε ξεχωριστές γραμμές
expanded_df = crimes_total_df \
    .withColumn("mo_array", split(col("mocodes"), " ")) \
    .withColumn("mo_code", explode(col("mo_array"))) \
    .withColumn("mo_code", trim(col("mo_code"))) \
    .filter(col("mo_code") != "")

# 2. Join με το λεξικό των περιγραφών
start_time=time.time()
shuffle_repl_nl = expanded_df.hint("shuffle_replicate_nl") \
    .join(codes_df.hint("shuffle_replicate_nl"), expanded_df["mo_code"] == codes_df["mocodes"], "left")
end_time=time.time()
shuffle_repl_nl.explain(mode="formatted")
result_df = shuffle_repl_nl.groupBy("mo_code","description").count().orderBy(col("count").desc())

result_df.show(truncate=False)
#result_df.explain("cost")

print("Dataframe API Execution time for Query 3 (shuffle replicate nl): {:.4f} sec".format(end_time - start_time))
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# == Physical Plan ==
# AdaptiveSparkPlan (16)
# +- BroadcastHashJoin LeftOuter BuildRight (15)
#    :- Project (10)
#    :  +- Filter (9)
#    :     +- Generate (8)
#    :        +- Union (7)
#    :           :- Project (3)
#    :           :  +- Filter (2)
#    :           :     +- Scan csv  (1)
#    :           +- Project (6)
#    :              +- Filter (5)
#    :                 +- Scan csv  (4)
#    +- BroadcastExchange (14)
#       +- Project (13)
#          +- Filter (12)
#             +- Scan text  (11)
#
#
# (1) Scan csv
# Output [28]: [dr_no#4133, date_rptd#4134, date_occ#4135, time_occ#4136, area#4137, area_name#4138, rpt_dist_no#4139, part_1_2#4140, crm_cd#4141, crm_cd_desc#4142, mocodes#4143, vict_age#4144, vict_sex#4145, vict_descent#4146, premis_cd#4147, premis_desc#4148, weapon_used_cd#4149, weapon_desc#4150, status#4151, status_desc#4152, crm_cd_1#4153, crm_cd_2#4154, crm_cd_3#4155, crm_cd_4#4156, location#4157, cross_street#4158, lat#4159, lon#4160]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2010_2019.csv]
# ReadSchema: struct<dr_no:string,date_rptd:string,date_occ:string,time_occ:string,area:string,area_name:string,rpt_dist_no:string,part_1_2:int,crm_cd:string,crm_cd_desc:string,mocodes:string,vict_age:string,vict_sex:string,vict_descent:string,premis_cd:string,premis_desc:string,weapon_used_cd:string,weapon_desc:string,status:string,status_desc:string,crm_cd_1:string,crm_cd_2:string,crm_cd_3:string,crm_cd_4:string,location:string,cross_street:string,lat:float,lon:float>
#
# (2) Filter
# Input [28]: [dr_no#4133, date_rptd#4134, date_occ#4135, time_occ#4136, area#4137, area_name#4138, rpt_dist_no#4139, part_1_2#4140, crm_cd#4141, crm_cd_desc#4142, mocodes#4143, vict_age#4144, vict_sex#4145, vict_descent#4146, premis_cd#4147, premis_desc#4148, weapon_used_cd#4149, weapon_desc#4150, status#4151, status_desc#4152, crm_cd_1#4153, crm_cd_2#4154, crm_cd_3#4155, crm_cd_4#4156, location#4157, cross_street#4158, lat#4159, lon#4160]
# Condition : ((size(split(mocodes#4143,  , -1), true) > 0) AND isnotnull(split(mocodes#4143,  , -1)))
#
# (3) Project
# Output [29]: [dr_no#4133, date_rptd#4134, date_occ#4135, time_occ#4136, area#4137, area_name#4138, rpt_dist_no#4139, part_1_2#4140, crm_cd#4141, crm_cd_desc#4142, mocodes#4143, vict_age#4144, vict_sex#4145, vict_descent#4146, premis_cd#4147, premis_desc#4148, weapon_used_cd#4149, weapon_desc#4150, status#4151, status_desc#4152, crm_cd_1#4153, crm_cd_2#4154, crm_cd_3#4155, crm_cd_4#4156, location#4157, cross_street#4158, lat#4159, lon#4160, split(mocodes#4143,  , -1) AS mo_array#4305]
# Input [28]: [dr_no#4133, date_rptd#4134, date_occ#4135, time_occ#4136, area#4137, area_name#4138, rpt_dist_no#4139, part_1_2#4140, crm_cd#4141, crm_cd_desc#4142, mocodes#4143, vict_age#4144, vict_sex#4145, vict_descent#4146, premis_cd#4147, premis_desc#4148, weapon_used_cd#4149, weapon_desc#4150, status#4151, status_desc#4152, crm_cd_1#4153, crm_cd_2#4154, crm_cd_3#4155, crm_cd_4#4156, location#4157, cross_street#4158, lat#4159, lon#4160]
#
# (4) Scan csv
# Output [28]: [dr_no#4189, date_rptd#4190, date_occ#4191, time_occ#4192, area#4193, area_name#4194, rpt_dist_no#4195, part_1_2#4196, crm_cd#4197, crm_cd_desc#4198, mocodes#4199, vict_age#4200, vict_sex#4201, vict_descent#4202, premis_cd#4203, premis_desc#4204, weapon_used_cd#4205, weapon_desc#4206, status#4207, status_desc#4208, crm_cd_1#4209, crm_cd_2#4210, crm_cd_3#4211, crm_cd_4#4212, location#4213, cross_street#4214, lat#4215, lon#4216]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv]
# ReadSchema: struct<dr_no:string,date_rptd:string,date_occ:string,time_occ:string,area:string,area_name:string,rpt_dist_no:string,part_1_2:int,crm_cd:string,crm_cd_desc:string,mocodes:string,vict_age:string,vict_sex:string,vict_descent:string,premis_cd:string,premis_desc:string,weapon_used_cd:string,weapon_desc:string,status:string,status_desc:string,crm_cd_1:string,crm_cd_2:string,crm_cd_3:string,crm_cd_4:string,location:string,cross_street:string,lat:float,lon:float>
#
# (5) Filter
# Input [28]: [dr_no#4189, date_rptd#4190, date_occ#4191, time_occ#4192, area#4193, area_name#4194, rpt_dist_no#4195, part_1_2#4196, crm_cd#4197, crm_cd_desc#4198, mocodes#4199, vict_age#4200, vict_sex#4201, vict_descent#4202, premis_cd#4203, premis_desc#4204, weapon_used_cd#4205, weapon_desc#4206, status#4207, status_desc#4208, crm_cd_1#4209, crm_cd_2#4210, crm_cd_3#4211, crm_cd_4#4212, location#4213, cross_street#4214, lat#4215, lon#4216]
# Condition : ((size(split(mocodes#4199,  , -1), true) > 0) AND isnotnull(split(mocodes#4199,  , -1)))
#
# (6) Project
# Output [29]: [dr_no#4189, date_rptd#4190, date_occ#4191, time_occ#4192, area#4193, area_name#4194, rpt_dist_no#4195, part_1_2#4196, crm_cd#4197, crm_cd_desc#4198, mocodes#4199, vict_age#4200, vict_sex#4201, vict_descent#4202, premis_cd#4203, premis_desc#4204, weapon_used_cd#4205, weapon_desc#4206, status#4207, status_desc#4208, crm_cd_1#4209, crm_cd_2#4210, crm_cd_3#4211, crm_cd_4#4212, location#4213, cross_street#4214, lat#4215, lon#4216, split(mocodes#4199,  , -1) AS mo_array#4462]
# Input [28]: [dr_no#4189, date_rptd#4190, date_occ#4191, time_occ#4192, area#4193, area_name#4194, rpt_dist_no#4195, part_1_2#4196, crm_cd#4197, crm_cd_desc#4198, mocodes#4199, vict_age#4200, vict_sex#4201, vict_descent#4202, premis_cd#4203, premis_desc#4204, weapon_used_cd#4205, weapon_desc#4206, status#4207, status_desc#4208, crm_cd_1#4209, crm_cd_2#4210, crm_cd_3#4211, crm_cd_4#4212, location#4213, cross_street#4214, lat#4215, lon#4216]
#
# (7) Union
#
# (8) Generate
# Input [29]: [dr_no#4133, date_rptd#4134, date_occ#4135, time_occ#4136, area#4137, area_name#4138, rpt_dist_no#4139, part_1_2#4140, crm_cd#4141, crm_cd_desc#4142, mocodes#4143, vict_age#4144, vict_sex#4145, vict_descent#4146, premis_cd#4147, premis_desc#4148, weapon_used_cd#4149, weapon_desc#4150, status#4151, status_desc#4152, crm_cd_1#4153, crm_cd_2#4154, crm_cd_3#4155, crm_cd_4#4156, location#4157, cross_street#4158, lat#4159, lon#4160, mo_array#4305]
# Arguments: explode(mo_array#4305), [dr_no#4133, date_rptd#4134, date_occ#4135, time_occ#4136, area#4137, area_name#4138, rpt_dist_no#4139, part_1_2#4140, crm_cd#4141, crm_cd_desc#4142, mocodes#4143, vict_age#4144, vict_sex#4145, vict_descent#4146, premis_cd#4147, premis_desc#4148, weapon_used_cd#4149, weapon_desc#4150, status#4151, status_desc#4152, crm_cd_1#4153, crm_cd_2#4154, crm_cd_3#4155, crm_cd_4#4156, ... 5 more fields], false, [mo_code#4336]
#
# (9) Filter
# Input [30]: [dr_no#4133, date_rptd#4134, date_occ#4135, time_occ#4136, area#4137, area_name#4138, rpt_dist_no#4139, part_1_2#4140, crm_cd#4141, crm_cd_desc#4142, mocodes#4143, vict_age#4144, vict_sex#4145, vict_descent#4146, premis_cd#4147, premis_desc#4148, weapon_used_cd#4149, weapon_desc#4150, status#4151, status_desc#4152, crm_cd_1#4153, crm_cd_2#4154, crm_cd_3#4155, crm_cd_4#4156, location#4157, cross_street#4158, lat#4159, lon#4160, mo_array#4305, mo_code#4336]
# Condition : NOT (trim(mo_code#4336, None) = )
#
# (10) Project
# Output [30]: [dr_no#4133, date_rptd#4134, date_occ#4135, time_occ#4136, area#4137, area_name#4138, rpt_dist_no#4139, part_1_2#4140, crm_cd#4141, crm_cd_desc#4142, mocodes#4143, vict_age#4144, vict_sex#4145, vict_descent#4146, premis_cd#4147, premis_desc#4148, weapon_used_cd#4149, weapon_desc#4150, status#4151, status_desc#4152, crm_cd_1#4153, crm_cd_2#4154, crm_cd_3#4155, crm_cd_4#4156, location#4157, cross_street#4158, lat#4159, lon#4160, mo_array#4305, trim(mo_code#4336, None) AS mo_code#4367]
# Input [30]: [dr_no#4133, date_rptd#4134, date_occ#4135, time_occ#4136, area#4137, area_name#4138, rpt_dist_no#4139, part_1_2#4140, crm_cd#4141, crm_cd_desc#4142, mocodes#4143, vict_age#4144, vict_sex#4145, vict_descent#4146, premis_cd#4147, premis_desc#4148, weapon_used_cd#4149, weapon_desc#4150, status#4151, status_desc#4152, crm_cd_1#4153, crm_cd_2#4154, crm_cd_3#4155, crm_cd_4#4156, location#4157, cross_street#4158, lat#4159, lon#4160, mo_array#4305, mo_code#4336]
#
# (11) Scan text
# Output [1]: [value#4121]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/MO_codes.txt]
# ReadSchema: struct<value:string>
#
# (12) Filter
# Input [1]: [value#4121]
# Condition : (NOT (regexp_extract(value#4121, ^(\d{4}), 1) = ) AND isnotnull(regexp_extract(value#4121, ^(\d{4}), 1)))
#
# (13) Project
# Output [2]: [regexp_extract(value#4121, ^(\d{4}), 1) AS mocodes#4123, regexp_extract(value#4121, ^\d{4}\s+(.*)$, 1) AS description#4127]
# Input [1]: [value#4121]
#
# (14) BroadcastExchange
# Input [2]: [mocodes#4123, description#4127]
# Arguments: HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=3102]
#
# (15) BroadcastHashJoin
# Left keys [1]: [mo_code#4367]
# Right keys [1]: [mocodes#4123]
# Join type: LeftOuter
# Join condition: None
#
# (16) AdaptiveSparkPlan
# Output [32]: [dr_no#4133, date_rptd#4134, date_occ#4135, time_occ#4136, area#4137, area_name#4138, rpt_dist_no#4139, part_1_2#4140, crm_cd#4141, crm_cd_desc#4142, mocodes#4143, vict_age#4144, vict_sex#4145, vict_descent#4146, premis_cd#4147, premis_desc#4148, weapon_used_cd#4149, weapon_desc#4150, status#4151, status_desc#4152, crm_cd_1#4153, crm_cd_2#4154, crm_cd_3#4155, crm_cd_4#4156, location#4157, cross_street#4158, lat#4159, lon#4160, mo_array#4305, mo_code#4367, mocodes#4123, description#4127]
# Arguments: isFinalPlan=false
#
#
# +-------+--------------------------------------------------------------------------------+-------+
# |mo_code|description                                                                     |count  |
# +-------+--------------------------------------------------------------------------------+-------+
# |0344   |Removes vict property                                                           |1002900|
# |1822   |Stranger                                                                        |548422 |
# |0416   |Hit-Hit w/ weapon                                                               |404773 |
# |0329   |Vandalized                                                                      |377536 |
# |0913   |Victim knew Suspect                                                             |278618 |
# |2000   |Domestic violence                                                               |256188 |
# |1300   |Vehicle involved                                                                |219082 |
# |0400   |Force used                                                                      |213165 |
# |1402   |Evidence Booked (any crime)                                                     |177470 |
# |1609   |Smashed                                                                         |131229 |
# |1309   |Susp uses vehicle                                                               |122108 |
# |1202   |Victim was aged (60 & over) or blind/physically disabled/unable to care for self|120238 |
# |0325   |Took merchandise                                                                |120159 |
# |1814   |Susp is/was current/former boyfriend/girlfriend                                 |118073 |
# |0444   |Pushed                                                                          |116763 |
# |1501   |Other MO (see rpt)                                                              |115589 |
# |1307   |Breaks window                                                                   |113609 |
# |0334   |Brandishes weapon                                                               |105665 |
# |2004   |Suspect is homeless/transient                                                   |93426  |
# |0432   |Intimidation                                                                    |83562  |
# +-------+--------------------------------------------------------------------------------+-------+
# only showing top 20 rows
#
# Dataframe API Execution time for Query 3 (shuffle replicate nl): 0.0111 sec

# %%
#implementation using RDD
from pyspark.sql import SparkSession
import time


sc = SparkSession \
    .builder \
    .appName("Query 3 implemented with RDD") \
    .getOrCreate() \
    .sparkContext

#Φορτώνουμε τα δεδομενα   
crimes_2010_2019 = sc.textFile("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2010_2019.csv") \
                .map(lambda x: (x.split(","))) # Split lines into a list of elements -> delimiter: ","

crimes_2020_2025 = sc.textFile("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv") \
                .map(lambda x: (x.split(","))) # Split lines into a list of elements -> delimiter: ","

crimes=crimes_2010_2019.union(crimes_2020_2025)

codes = spark.read.text("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/MO_codes.txt")
codes = codes.withColumn("mocodes", regexp_extract(col("value"), r"^(\d{4})", 1)) \
                   .withColumn("description", regexp_extract(col("value"), r"^\d{4}\s+(.*)$", 1)) \
                   .drop("value")

codes_rdd = codes.rdd.map(lambda row: (row['mocodes'], row['description']))


def extract_mocodes(row):
    mocodes_str = row[10]  # 11η στήλη στο CSV
    if not mocodes_str:
        return []
    # split σε πολλούς κωδικούς αν υπάρχουν
    return [(c.strip(), 1) for c in mocodes_str.split() if c.strip()]

crimes_rdd = crimes.flatMap(extract_mocodes)

# --- 4. Μετράμε συχνότητες εμφάνισης ανά MO code ---
counts_rdd = crimes_rdd.reduceByKey(lambda a, b: a + b)  # (mocode, count)
start_time=time.time()
# --- 5. Κλασικό join με το codes_rdd για descriptions ---
joined_rdd = counts_rdd.join(codes_rdd)  # (mocode, (count, description))

# --- 6. Ταξινόμηση κατά φθίνουσα συχνότητα ---
result_rdd = joined_rdd.map(lambda x: (x[0], x[1][1], x[1][0])) \
                       .sortBy(lambda x: x[2], ascending=False)
end_time = time.time()
# --- 7. Προβολή αποτελεσμάτων ---
for row in result_rdd.take(10):
    print(row)


print("RDD classic join execution time: {:.4f} sec".format(end_time - start_time))
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ('0344', 'Removes vict property', 207949)
# ('0416', 'Hit-Hit w/ weapon', 164631)
# ('1822', 'Stranger', 123039)
# ('0913', 'Victim knew Suspect', 104781)
# ('0400', 'Force used', 75879)
# ('1814', 'Susp is/was current/former boyfriend/girlfriend', 74044)
# ('2000', 'Domestic violence', 64107)
# ('1300', 'Vehicle involved', 63441)
# ('0444', 'Pushed', 62748)
# ('1813', 'Susp is/was current/former spouse/co-habitant', 52548)
# RDD classic join execution time: 9.7663 sec
